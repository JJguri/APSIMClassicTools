# %%
#####################################################################################################################
#Developed by Jonathan Ojeda 18/1/2021 QAAFI UQ
# Code functionalities:
# Bar plotting in different ways
#####################################################################################################################

# %%
#import libraries
import random as rd
import os
import sqlite3
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import dateutil
import pylab as py
import seaborn as sns
import scipy 
from scipy import stats
import sklearn.metrics
from numpy  import array
import glob
import functools
from functools import reduce
import matplotlib.ticker as ticker
import cartopy.io.shapereader as shpreader
import xarray as xr
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.ticker as mticker
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import matplotlib as mpl
from mpl_toolkits.axes_grid.inset_locator import (inset_axes, InsetPosition,
                                                  mark_inset)

from sklearn.cluster import KMeans

#Extend screen
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <ipython-input-1-f27bbb6f6f6b>:28: MatplotlibDeprecationWarning:
# The mpl_toolkits.axes_grid module was deprecated in Matplotlib 2.1 and will be removed two minor releases later. Use mpl_toolkits.axes_grid1 and mpl_toolkits.axisartist, which provide the same functionality instead.
#   from mpl_toolkits.axes_grid.inset_locator import (inset_axes, InsetPosition,
# <style>.container { width:100% !important; }</style>

# %%
df = pd.read_csv(r'C:\Users\uqjojeda\Nextcloud\PURTERRA-A0131\2020\Validation\data.csv')

# %%
df
# Out:
#     state             loc               loc2  year    harvest    cultivar  \
# 0      TX  CollegeStation  CollegeStation-TX  2008     August      SugarT
# 1      TX  CollegeStation  CollegeStation-TX  2008     August   GrazeAll3
# 2      TX  CollegeStation  CollegeStation-TX  2008     August      _22053
# 3      TX  CollegeStation  CollegeStation-TX  2008     August  GrazeNBale
# 4      TX  CollegeStation  CollegeStation-TX  2008     August        M81E
# ..    ...             ...                ...   ...        ...         ...
# 636    NC           Roper           Roper-NC  2012  September  GrazeNBale
# 637    NC           Roper           Roper-NC  2012  September        M81E
# 638    NC           Roper           Roper-NC  2012  September        M81E
# 639    NC           Roper           Roper-NC  2012  September        M81E
# 640    NC           Roper           Roper-NC  2012  September        M81E
#
#      rep  biomass
# 0      1    11.54
# 1      1    12.99
# 2      1    10.29
# ...

# %%
fig = plt.figure(figsize=(15,5))

sns.boxplot(x="loc2", y="biomass", data=df, hue='cultivar',linewidth=1)
plt.ylabel('Biomass ($t\,ha^{-1}$)', fontsize =20)
plt.xlabel('', fontsize =20)
ax = plt.gca()
ax.grid(True, 'major', color='w', linestyle='-', linewidth=0.5)
ax.grid(True, 'minor', color='0.92', linestyle='-', linewidth=0.7)
ax.patch.set_facecolor('0.96')
ax.set_axisbelow(True)
ax.yaxis.set_tick_params(labelsize=20)
ax.xaxis.set_tick_params(labelsize=13)
ax.set_xticklabels(ax.get_xticklabels(),rotation=0)
    
plt.legend(prop=dict(size=20),bbox_to_anchor=(1,1), loc=2, borderaxespad=0., frameon=False)
plt.subplots_adjust(wspace=0.2, hspace=0.2)
#plt.savefig(r'C:\Users\uqjojeda\Nextcloud\PURTERRA-A0131\2020\Validation\data.png', dpi=300,bbox_inches='tight')

# %%
tkt_plot_detailed=sns.catplot(x="year", y="biomass", data=df, hue='cultivar', linewidth=1, kind='box', col='loc2', 
            col_wrap=4, legend=False)
tkt_plot_detailed.set_axis_labels("", "Biomass ($t\,ha^{-1}$)",fontsize= 25)
tkt_plot_detailed.set_titles(col_template="{col_name}", fontweight='bold', size=25)
for ax in tkt_plot_detailed.axes.flatten():

    ax.grid(True, 'major', color='w', linestyle='-', linewidth=0.5)
    ax.grid(True, 'minor', color='0.92', linestyle='-', linewidth=0.7)
    ax.patch.set_facecolor('0.90')
    ax.set_axisbelow(True)
    ax.yaxis.set_tick_params(labelsize=20)
    ax.xaxis.set_tick_params(labelsize=25)
    ax.set_xticklabels(ax.get_xticklabels(),rotation=90)

plt.legend(prop=dict(size=20),bbox_to_anchor=(1.1, 0.8), loc=2, borderaxespad=0., frameon=False)
plt.subplots_adjust(wspace=0.03, hspace=0.15)

#plt.savefig(r'C:\Users\uqjojeda\Nextcloud\PURTERRA-A0131\2020\Validation\data2.png', dpi=300,bbox_inches='tight')
