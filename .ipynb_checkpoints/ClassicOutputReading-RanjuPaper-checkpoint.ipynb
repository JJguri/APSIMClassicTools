# %%
#####################################################################################################################
#Developed by Jonathan Ojeda 1/4/2021 QAAFI UQ
# Code functionalities:
# Import apsim classic files and compare OBS vs PRE data
# Read several files from a folder and merge them in a single pandas dataframe
# Create scatter plots and add error bars
#####################################################################################################################

# %%
#import libraries
import random as rd
import os
import sqlite3
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import dateutil
import pylab as py
import seaborn as sns
import scipy 
from scipy import stats
import sklearn.metrics
from numpy  import array
import glob
import functools
from functools import reduce
import matplotlib.ticker as ticker
import cartopy.io.shapereader as shpreader
import xarray as xr
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.ticker as mticker
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import matplotlib as mpl
from mpl_toolkits.axes_grid.inset_locator import (inset_axes, InsetPosition,
                                                  mark_inset)

from sklearn.cluster import KMeans

#Extend screen
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
df= pd.read_csv(r'C:\Users\uqjojeda\Dropbox\RanjuPaper2\APSIM_cressy\new\CR_SM_P1_M1_lowAnnualOutput.out')
df.drop(df.loc[0:2].index, inplace=True)
df[['Year','HarvestTuberWt','InCropRainfall','InCropRunoff','InCropDrainage','InCropEs','MaturityDAS',
        'emergence_das','InCropIrrigation','InCropNLeaching', 'Title']] = df['ApsimVersion = 7.10 r4210'].str.split(n=10, expand=True)
a = df.drop(['ApsimVersion = 7.10 r4210'], axis=1)
    #Change dtype from string to float
a["HarvestTuberWt"] = a["HarvestTuberWt"].astype(str).astype(float)
a["InCropRainfall"] = a["InCropRainfall"].astype(str).astype(float)
a["InCropRunoff"] = a["InCropRunoff"].astype(str).astype(float)
a["InCropDrainage"] = a["InCropDrainage"].astype(str).astype(float)
a["InCropEs"] = a["InCropEs"].astype(str).astype(float)
a["MaturityDAS"] = a["MaturityDAS"].astype(str).astype(float)
a["emergence_das"] = a["emergence_das"].astype(str).astype(float)
a["InCropIrrigation"] = a["InCropIrrigation"].astype(str).astype(float)
b = a[a['HarvestTuberWt'] != 0]
#Create categories
b['water_mod'] = b['Title'].str.slice(3,5)
b['apsim_mod'] = b['Title'].str.slice(6,8)
b['manag_mod'] = b['Title'].str.slice(9,11)
b['env'] = b['Title'].str.slice(12,15)
#c = b.drop(['Title'], axis=1)
b
# Out:
# <ipython-input-119-16c3fac546ee>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b['water_mod'] = b['Title'].str.slice(3,5)
# <ipython-input-119-16c3fac546ee>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b['apsim_mod'] = b['Title'].str.slice(6,8)
# <ipython-input-119-16c3fac546ee>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b['manag_mod'] = b['Title'].str.slice(9,11)
# <ipython-input-119-16c3fac546ee>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b['env'] = b['Title'].str.slice(12,15)
#      Year  HarvestTuberWt  InCropRainfall  InCropRunoff  InCropDrainage  \
# 4    1902         1388.89           165.0         0.000           6.575
# 5    1903         1203.00           205.6         0.000           0.388
# 7    1905         1347.80           221.5         0.073           3.708
# 9    1907         1323.01           182.6         1.100          11.701
# 10   1908         1119.53           224.4        10.689          39.355
# ..    ...             ...             ...           ...             ...
# 118  2016         1144.09           237.1        10.121          13.427
# 119  2017         1131.22           236.9         1.308           9.615
# 120  2018          978.98           241.6        12.826           5.151
# 121  2019         1059.94           246.2         0.014           8.446
# 122  2020         1058.74           306.0         0.030          34.755
#
#      InCropEs  MaturityDAS  emergence_das  InCropIrrigation InCropNLeaching  \
# 4     187.339        169.0           25.0             295.0             0.7
# 5     183.668        163.0           24.0             340.0             0.0
# 7     180.777        168.0           26.0             310.0             0.2
# 9     211.837        176.0           28.0             280.0             2.9
# 10    185.265        166.0           25.0             295.0             0.3
# ..        ...          ...            ...               ...             ...
# 118   175.956        160.0           23.0             295.0             0.2
# 119   194.677        166.0           26.0             235.0             0.4
# 120   194.628        164.0           25.0             265.0             0.0
# 121   193.107        169.0           26.0             265.0             0.0
# 122   191.159        173.0           28.0             325.0             0.0
#
#                Title water_mod apsim_mod manag_mod  env
# 4    CR_SM_P1_M1_low        SM        P1        M1  low
# 5    CR_SM_P1_M1_low        SM        P1        M1  low
# 7    CR_SM_P1_M1_low        SM        P1        M1  low
# 9    CR_SM_P1_M1_low        SM        P1        M1  low
# 10   CR_SM_P1_M1_low        SM        P1        M1  low
# ..               ...       ...       ...       ...  ...
# 118  CR_SM_P1_M1_low        SM        P1        M1  low
# 119  CR_SM_P1_M1_low        SM        P1        M1  low
# 120  CR_SM_P1_M1_low        SM        P1        M1  low
# 121  CR_SM_P1_M1_low        SM        P1        M1  low
# 122  CR_SM_P1_M1_low        SM        P1        M1  low
#
# [109 rows x 15 columns]

# %%
#read simulated data from APSIM Classic out files
filelist = glob.glob(r'C:\Users\uqjojeda\Dropbox\RanjuPaper2\APSIM_cressy\new\* AnnualOutput.out')
frame = pd.DataFrame()
list = []

for file in filelist:
    df = pd.read_csv(file)
    df.drop(df.loc[0:2].index, inplace=True)
    df[['Year','HarvestTuberWt','InCropRainfall','InCropRunoff','InCropDrainage','InCropEs','MaturityDAS',
        'emergence_das','InCropIrrigation','InCropNLeaching', 'Title']] = df['ApsimVersion = 7.10 r4210'].str.split(n=10, expand=True) #n= is columns-1
    a = df.drop(['ApsimVersion = 7.10 r4210'], axis=1)
    #Change dtype from string to float
    a["HarvestTuberWt"] = a["HarvestTuberWt"].astype(str).astype(float)
    a["InCropRainfall"] = a["InCropRainfall"].astype(str).astype(float)
    a["InCropRunoff"] = a["InCropRunoff"].astype(str).astype(float)
    a["InCropDrainage"] = a["InCropDrainage"].astype(str).astype(float)
    a["InCropEs"] = a["InCropEs"].astype(str).astype(float)
    a["MaturityDAS"] = a["MaturityDAS"].astype(str).astype(float)
    a["InCropIrrigation"] = a["InCropIrrigation"].astype(str).astype(float)
    #a['InCropNLeaching'] = a['InCropNLeaching'].astype(str).astype(float)
    #a["emergence_das"] = a["emergence_das"].astype(str).astype(float)
    #b = a[a['HarvestTuberWt'] != 0]
    #Create categories
    a['soil_mod'] = a['Title'].str.slice(3,5)
    a['apsim_mod'] = a['Title'].str.slice(6,8)
    a['manag_mod'] = a['Title'].str.slice(9,11)
    a['env'] = a['Title'].str.slice(12,15)
    b = a.drop(['Title'], axis=1)
    
    list.append(b)
    
all_sim = pd.concat(list)

# %%
all_sim
# Out:
#      Year  HarvestTuberWt  InCropRainfall  InCropRunoff  InCropDrainage  \
# 3    1900            0.00            23.9         0.732           4.184
# 4    1902         1496.71           164.1         0.000           6.773
# 5    1903         1335.40           199.4         0.000           0.657
# 6    1903            0.00           104.4         2.307           2.834
# 7    1905         1446.76           218.6         0.057           3.782
# ..    ...             ...             ...           ...             ...
# 118  2016         1466.62           237.2         9.017          67.170
# 119  2017         1582.93           218.3         3.465          11.491
# 120  2018         1540.72           224.2         0.000           9.130
# 121  2019         1513.12           237.0         0.732          18.172
# 122  2020         1388.66           281.6         1.857          23.030
#
#      InCropEs  MaturityDAS emergence_das  InCropIrrigation InCropNLeaching  \
# 3     102.563         52.0            20              68.5             0.3
# 4     171.874        162.0            20             310.0             0.7
# 5     166.332        157.0            19             355.0             0.1
# 6     144.669         52.0            20              55.0             0.0
# 7     161.781        161.0            20             325.0             0.2
# ..        ...          ...           ...               ...             ...
# 118   201.821        154.0             ?             465.0               ?
# 119   190.689        157.0             ?             270.0               ?
# 120   170.144        157.0             ?             435.0               ?
# 121   206.345        162.0             ?             330.0               ?
# 122   185.196        164.0             ?             390.0               ?
#
#     soil_mod apsim_mod manag_mod  env
# 3         SM        P1        M1  low
# 4         SM        P1        M1  low
# 5         SM        P1        M1  low
# 6         SM        P1        M1  low
# 7         SM        P1        M1  low
# ..       ...       ...       ...  ...
# 118       SW        P2        M2  low
# 119       SW        P2        M2  low
# 120       SW        P2        M2  low
# 121       SW        P2        M2  low
# 122       SW        P2        M2  low
#
# [962 rows x 14 columns]

# %%
all_sim.env.unique()
# Out:
# array(['low'], dtype=object)

# %%
df= pd.read_csv(r'C:\Users\uqjojeda\Dropbox\RanjuPaper2\APSIM_cressy\new\CR_SM_P1_M1_lowAnnualOutput.out')
df.drop(df.loc[0:2].index, inplace=True)
df[['Year','HarvestTuberWt','InCropRainfall','InCropRunoff','InCropDrainage','InCropEs','MaturityDAS',
        'emergence_das','InCropIrrigation','InCropNLeaching', 'Title']] = df['ApsimVersion = 7.10 r4210'].str.split(n=10, expand=True)
a = df.drop(['ApsimVersion = 7.10 r4210'], axis=1)
    #Change dtype from string to float
a["HarvestTuberWt"] = a["HarvestTuberWt"].astype(str).astype(float)
a["InCropRainfall"] = a["InCropRainfall"].astype(str).astype(float)
a["InCropRunoff"] = a["InCropRunoff"].astype(str).astype(float)
a["InCropDrainage"] = a["InCropDrainage"].astype(str).astype(float)
a["InCropEs"] = a["InCropEs"].astype(str).astype(float)
a["MaturityDAS"] = a["MaturityDAS"].astype(str).astype(float)
a["emergence_das"] = a["emergence_das"].astype(str).astype(float)
a["InCropIrrigation"] = a["InCropIrrigation"].astype(str).astype(float)
b = a[a['HarvestTuberWt'] != 0]
#Create categories
b['water_mod'] = b['Title'].str.slice(3,5)
b['apsim_mod'] = b['Title'].str.slice(6,8)
b['manag_mod'] = b['Title'].str.slice(9,11)
b['env'] = b['Title'].str.slice(12,15)
#c = b.drop(['Title'], axis=1)
b
# Out:
# <ipython-input-119-16c3fac546ee>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b['water_mod'] = b['Title'].str.slice(3,5)
# <ipython-input-119-16c3fac546ee>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b['apsim_mod'] = b['Title'].str.slice(6,8)
# <ipython-input-119-16c3fac546ee>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b['manag_mod'] = b['Title'].str.slice(9,11)
# <ipython-input-119-16c3fac546ee>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   b['env'] = b['Title'].str.slice(12,15)
#      Year  HarvestTuberWt  InCropRainfall  InCropRunoff  InCropDrainage  \
# 4    1902         1388.89           165.0         0.000           6.575
# 5    1903         1203.00           205.6         0.000           0.388
# 7    1905         1347.80           221.5         0.073           3.708
# 9    1907         1323.01           182.6         1.100          11.701
# 10   1908         1119.53           224.4        10.689          39.355
# ..    ...             ...             ...           ...             ...
# 118  2016         1144.09           237.1        10.121          13.427
# 119  2017         1131.22           236.9         1.308           9.615
# 120  2018          978.98           241.6        12.826           5.151
# 121  2019         1059.94           246.2         0.014           8.446
# 122  2020         1058.74           306.0         0.030          34.755
#
#      InCropEs  MaturityDAS  emergence_das  InCropIrrigation InCropNLeaching  \
# 4     187.339        169.0           25.0             295.0             0.7
# 5     183.668        163.0           24.0             340.0             0.0
# 7     180.777        168.0           26.0             310.0             0.2
# 9     211.837        176.0           28.0             280.0             2.9
# 10    185.265        166.0           25.0             295.0             0.3
# ..        ...          ...            ...               ...             ...
# 118   175.956        160.0           23.0             295.0             0.2
# 119   194.677        166.0           26.0             235.0             0.4
# 120   194.628        164.0           25.0             265.0             0.0
# 121   193.107        169.0           26.0             265.0             0.0
# 122   191.159        173.0           28.0             325.0             0.0
#
#                Title water_mod apsim_mod manag_mod  env
# 4    CR_SM_P1_M1_low        SM        P1        M1  low
# 5    CR_SM_P1_M1_low        SM        P1        M1  low
# 7    CR_SM_P1_M1_low        SM        P1        M1  low
# 9    CR_SM_P1_M1_low        SM        P1        M1  low
# 10   CR_SM_P1_M1_low        SM        P1        M1  low
# ..               ...       ...       ...       ...  ...
# 118  CR_SM_P1_M1_low        SM        P1        M1  low
# 119  CR_SM_P1_M1_low        SM        P1        M1  low
# 120  CR_SM_P1_M1_low        SM        P1        M1  low
# 121  CR_SM_P1_M1_low        SM        P1        M1  low
# 122  CR_SM_P1_M1_low        SM        P1        M1  low
#
# [109 rows x 15 columns]

# %%
#all_sim.to_csv(r'C:\Users\uqjojeda\Dropbox\RanjuPaper2\variance\data.csv')

# %%
all_sim.manag_mod.unique()
# Out:
# array(['M1'], dtype=object)

# %%
all_sim.HarvestTuberWt.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>
